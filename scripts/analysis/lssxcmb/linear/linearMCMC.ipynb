# %%
chain = sampler.get_chain(flat=False)
chain.shape
# Out:
# (10, 44, 22)

# %%
import matplotlib.pyplot as plt

# %%
for i in range(44):
    plt.plot(chain[:, i, 0])

# %%
xs.mean(axis=0)
# Out:
# array([ 1.36127625e-16, -7.35901938e-13, -2.24149689e-14,  8.44434309e-13,
#        -1.33683121e-12,  1.04826299e-12, -1.80400245e-16, -1.69861609e-16,
#        -5.65875161e-17, -5.92924742e-17,  2.48482816e-16,  1.84448719e-16,
#        -2.96485436e-15, -2.85698722e-16,  4.42485345e-15, -9.28282898e-17,
#        -2.34598190e-17,  1.31747039e-17, -4.69889241e-15, -6.01042157e-15,
#         7.16198013e-15])

# %%
chain[]
